# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
x=np.array([5,15,25,35,45,55]).reshape(-1,1)
y=np.array([5,20,14,32,22,35])
plt.scatter(x,y)

# %%
model=LinearRegression()
model.fit(x,y)
print(model.intercept_)
print(model.coef_)
print(model.score(x,y))
y_pred=model.predict(x)
print(y_pred)
# Out:
# 6.419047619047616
# [0.49714286]
# 0.6938731856378915
# [ 8.9047619  13.87619048 18.84761905 23.81904762 28.79047619 33.76190476]

# %%
print(model.score(x,y_pred))
# Out:
# 1.0

# %%
plt.scatter(x,y)

# %%
plt.plot(x,y_pred)

# %%
print(model.intercept_+model.coef_*x)
# Out:
# [[ 8.9047619 ]
#  [13.87619048]
#  [18.84761905]
#  [23.81904762]
#  [28.79047619]
#  [33.76190476]]

# %%
x_new=np.arange(5).reshape((-1,1))
print(x_new)
# Out:
# [[0]
#  [1]
#  [2]
#  [3]
#  [4]]

# %%
y_new=model.predict(x_new)
print(y_new)
# Out:
# [6.41904762 6.91619048 7.41333333 7.91047619 8.40761905]

# %%
plt.scatter(x_new,y_new)
plt.plot(x_new,y_new)
