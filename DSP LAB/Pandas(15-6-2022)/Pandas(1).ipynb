# %%
import pandas as pd
df=pd.read_csv("bollywood.csv")
df
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1    18-Apr-14                     2 States          LW    Romance
# 1       2     4-Jan-13                 Table No. 21           N  Thriller
# 2       3    18-Jul-14           Amit Sahni Ki List           N     Comedy
# 3       4     4-Jan-13             Rajdhani Express           N     Drama
# 4       5     4-Jul-14                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N     Comedy
# 145   146    13-Mar-15                         NH10           N   Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148    20-Mar-15                     Hunterrr           N     Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS     Action
#
# ...

# %%
df["Budget"].max()
# Out:
# 150

# %%
df["YoutubeLikes"].max()
# Out:
# 101275

# %%
df["YoutubeDislikes"].min()
# Out:
# 1

# %%
df.head(5)
# Out:
#    SlNo Release Date           MovieName ReleaseTime      Genre  Budget  \
# 0     1    18-Apr-14            2 States          LW    Romance      36
# 1     2     4-Jan-13        Table No. 21           N  Thriller       10
# 2     3    18-Jul-14  Amit Sahni Ki List           N     Comedy      10
# 3     4     4-Jan-13    Rajdhani Express           N     Drama        7
# 4     5     4-Jul-14        Bobby Jasoos           N     Comedy      18
#
#    BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 0               104.00       8576361         26622             2527
# 1                12.00       1087320          1129              137
# 2                 4.00        572336           586               54
# 3                 0.35         42626            86               19
# 4                10.80       3113427          4512             1224

# %%
df.tail(5)
# Out:
#      SlNo Release Date                    MovieName ReleaseTime     Genre  \
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N    Comedy
# 145   146    13-Mar-15                         NH10           N  Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N    Comedy
# 147   148    20-Mar-15                     Hunterrr           N    Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS    Action
#
#      Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 144      15                30.00       3250917          8185              615
# 145      13                32.10       5592977         15464             1513
# 146      32                12.00       2316047          4289              807
# 147       5                11.89       4674795          3706              762
# 148     150               120.00       4740727         13466             2649

# %%
df[["SlNo","Release Date"]]
# Out:
#      SlNo Release Date
# 0       1    18-Apr-14
# 1       2     4-Jan-13
# 2       3    18-Jul-14
# 3       4     4-Jan-13
# 4       5     4-Jul-14
# ..    ...          ...
# 144   145    27-Feb-15
# 145   146    13-Mar-15
# 146   147    20-Mar-15
# 147   148    20-Mar-15
# 148   149    23-May-14
#
# [149 rows x 2 columns]

# %%
list(df.columns)
# Out:
# ['SlNo',
#  'Release Date',
#  'MovieName',
#  'ReleaseTime',
#  'Genre',
#  'Budget',
#  'BoxOfficeCollection',
#  'YoutubeViews',
#  'YoutubeLikes',
#  'YoutubeDislikes']

# %%
df.shape
# Out:
# (149, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SlNo                 149 non-null    int64
#  1   Release Date         149 non-null    object
#  2   MovieName            149 non-null    object
#  3   ReleaseTime          149 non-null    object
#  4   Genre                149 non-null    object
#  5   Budget               149 non-null    int64
#  6   BoxOfficeCollection  149 non-null    float64
#  7   YoutubeViews         149 non-null    int64
#  8   YoutubeLikes         149 non-null    int64
#  9   YoutubeDislikes      149 non-null    int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 11.8+ KB

# %%
df.Genre.value_counts()
# Out:
# Comedy       36
#  Drama       35
# Thriller     26
# Romance      25
# Action       21
# Thriller      3
# Action        3
# Name: Genre, dtype: int64

# %%
pd.crosstab(df["Genre"],df["Release Date"] )
# Out:
# Release Date  1-Feb-13  1-Mar-13  1-Nov-13  10-Jan-14  10-May-13  11-Apr-14  \
# Genre
#  Drama               0         0         0          0          0          0
# Action               0         0         1          0          0          0
# Action               0         0         0          0          0          0
# Comedy               0         0         0          1          1          0
# Romance              0         0         0          1          0          0
# Thriller             0         1         0          0          0          1
# Thriller             1         0         0          0          0          0
#
# Release Date  11-Jan-13  11-Jul-14  11-Oct-13  12-Apr-13  ...  7-Jun-13  \
# Genre                                                     ...
#  Drama                1          0          0          0  ...         0
# Action                0          0          0          1  ...         0
# Action                0          0          0          0  ...         0
# ...

# %%
import pandas as pd
df=pd.read_csv("bollywood.csv")
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SlNo                 149 non-null    int64
#  1   Release Date         149 non-null    object
#  2   MovieName            149 non-null    object
#  3   ReleaseTime          149 non-null    object
#  4   Genre                149 non-null    object
#  5   Budget               149 non-null    int64
#  6   BoxOfficeCollection  149 non-null    float64
#  7   YoutubeViews         149 non-null    int64
#  8   YoutubeLikes         149 non-null    int64
#  9   YoutubeDislikes      149 non-null    int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 11.8+ KB
# None

# %%
a=df.groupby(["Genre"])
print(a.get_group("Comedy"))
# Out:
#      SlNo Release Date                    MovieName ReleaseTime   Genre  \
# 2       3    18-Jul-14           Amit Sahni Ki List           N  Comedy
# 4       5     4-Jul-14                 Bobby Jasoos           N  Comedy
# 6       7    19-Sep-14                Daawat-E-Ishq           N  Comedy
# 7       8    11-Jan-13   Matru Ki Bijlee Ka Mandola           N  Comedy
# 8       9    10-Jan-14                 Dedh Ishqiya          LW  Comedy
# 14     15     8-Aug-14                Entertainment           N  Comedy
# 17     18     6-Jun-14                   Filmistaan          HS  Comedy
# 18     19    12-Sep-14                Finding Fanny           N  Comedy
# 19     20    13-Jun-14                        Fugly          HS  Comedy
# 39     40    20-Jun-14                   Humshakals          HS  Comedy
# 46     47    15-Mar-13           Mere Dad Ki Maruti           N  Comedy
# 47     48    15-Mar-13                    Jolly LLB           N  Comedy
# ...

# %%
a.count()
# Out:
#            SlNo  Release Date  MovieName  ReleaseTime  Budget  \
# Genre
#  Drama       35            35         35           35      35
# Action       21            21         21           21      21
# Action        3             3          3            3       3
# Comedy       36            36         36           36      36
# Romance      25            25         25           25      25
# Thriller     26            26         26           26      26
# Thriller      3             3          3            3       3
#
#            BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# Genre
#  Drama                      35            35            35               35
# Action                      21            21            21               21
# Action                       3             3             3                3
# Comedy                      36            36            36               36
# ...

# %%
df.shape[0]
# Out:
# 149

# %%
(df[df.ReleaseTime=='FS'].Genre.value_counts())
# Out:
#  Drama      4
# Thriller    4
# Action      3
# Romance     3
# Comedy      3
# Name: Genre, dtype: int64

# %%
df.ReleaseTime.value_counts()
# Out:
# N     99
# HS    18
# FS    17
# LW    15
# Name: ReleaseTime, dtype: int64

# %%
pd.crosstab(df.Genre,df.ReleaseTime)
# Out:
# ReleaseTime  FS  HS  LW   N
# Genre
#  Drama        4   6   1  24
# Action        3   3   3  12
# Action        0   0   0   3
# Comedy        3   5   5  23
# Romance       3   3   4  15
# Thriller      4   1   1  20
# Thriller      0   0   1   2

# %%
df['Release Date']=pd.to_datetime(df['Release Date'])
df['month']=df['Release Date'].dt.month
df.month.value_counts()
# Out:
# 1     20
# 3     19
# 5     18
# 7     16
# 2     16
# 4     11
# 9     10
# 6     10
# 11    10
# 10     9
# 8      8
# 12     2
# Name: month, dtype: int64

# %%
df['Release Date']=pd.to_datetime(df['Release Date'])
df['month']=df['Release Date'].dt.month
df.month.value_counts().max()
# Out:
# 20

# %%
df[df.Budget>=25]['Release Date'].dt.month.value_counts()
# Out:
# 2     9
# 1     8
# 3     7
# 8     7
# 11    6
# 7     6
# 9     5
# 6     5
# 4     4
# 10    4
# 5     3
# 12    2
# Name: Release Date, dtype: int64

# %%
df['ROI']=(df.BoxOfficeCollection-df.Budget)/df.Budget
df.sort_values(by='ROI').MovieName[140: ]
# Out:
# 101           Bhaag Milkha Bhaag
# 37     Humpty Sharma Ki Dulhania
# 128                       Shahid
# 58                      Mary Kom
# 87                        Fukrey
# 135                 The Lunchbox
# 132                  Grand Masti
# 89                            PK
# 64                    Aashiqui 2
# Name: MovieName, dtype: object

# %%
df.groupby(by='ReleaseTime').ROI.mean()
# Out:
# ReleaseTime
# FS    0.973853
# HS    0.850867
# LW    1.127205
# N     0.657722
# Name: ROI, dtype: float64
